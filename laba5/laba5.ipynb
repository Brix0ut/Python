# %% [markdown]
# # Лабораторна робота №5

# %% [markdown]
# ## Завдання 1

# %%
hat_list = [1, 2, 3, 4, 5] 

hat_list[2] = int(input("Введіть ціле число для заміни середнього елемента: "))

del hat_list[-1]

print("Довжина списку:", len(hat_list))

print(hat_list)
# Out:
# Введіть ціле число для заміни середнього елемента:  100
# Довжина списку: 4
# [1, 2, 100, 4]

# %% [markdown]
# ## Завдання 2

# %%
my_list = [64, 34, 25, 12, 22, 11, 90]
print("Початковий список:", my_list)

n = len(my_list)

for i in range(n - 1):
    for j in range(n - 1 - i):
        if my_list[j] > my_list[j + 1]:
            my_list[j], my_list[j + 1] = my_list[j + 1], my_list[j]

print("Відсортований список:", my_list)
# Out:
# Початковий список: [64, 34, 25, 12, 22, 11, 90]
# Відсортований список: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# ## Завдання 3

# %%
my_list = [1, 2, 4, 4, 1, 4, 2, 6, 2, 9]
unique_list = []

for number in my_list:
    if number not in unique_list:
        unique_list.append(number)

my_list = unique_list

print("The list with unique elements only:")
print(my_list)
# Out:
# The list with unique elements only:
# [1, 2, 4, 6, 9]

# %% [markdown]
# ## Завдання 4

# %%
board = [["_" for j in range(8)] for i in range(8)]

board[0][0] = "T"
board[0][7] = "T"
board[7][0] = "T"
board[7][7] = "T"

for row in board:
    print(" ".join(row))
# Out:
# T _ _ _ _ _ _ T
# _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _
# T _ _ _ _ _ _ T

# %% [markdown]
# # Контрольні питання

# %% [markdown]
# ## 1

# %%
list_1 = ["A", "B", "C"]
list_2 = list_1
list_3 = list_2

del list_1[0]
del list_2[0]

print (list_3)
# Out:
# ['C']

# %% [markdown]
# ## 2

# %%
list_1 = ["A", "B", "C"]
list_2 = list_1
list_3 = list_2

del list_1[0]
del list_2

print (list_3)
# Out:
# ['B', 'C']

# %% [markdown]
# ## 3

# %%
list_1 = ["A", "B", "C"]
list_2 = list_1
list_3 = list_2

del list_1[0]
del list_2[:]

print (list_3)
# Out:
# []

# %% [markdown]
# ## 4

# %%
list_1 = ["A", "B", "C"]
list_2 = list_1[:]
list_3 = list_2[:]

del list_1[0]
del list_2[0]

print (list_3)
# Out:
# ['A', 'B', 'C']
